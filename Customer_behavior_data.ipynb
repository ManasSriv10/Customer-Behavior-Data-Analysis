# %% [markdown]
# # Installing the Pandas Library

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\manas srivastava\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\manas srivastava\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\manas srivastava\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manas srivastava\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\manas srivastava\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\manas srivastava\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Reading the data and importing it

# %%
data= pd.read_excel('customer_data.xlsx')
data.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount Customer_Lifespan_Months  \
# 0                      10                   98.241                        3
# 1                      15                  157.640                        4
# 2                       1                   41.252                        1
# 3                       6                   67.329                        1
# 4                       3                   52.763                        1
#
#   Purchase_Channel Date_of_Purchase Churn_Status
# 0           Online       2022-03-05          Yes
# 1         In-store       2023-07-08          Yes
# 2           Online       2023-01-30           No
# 3         In-store       2023-06-01           No
# 4           Online       2022-09-23           No

# %% [markdown]
# # Checking the missing values in dataset

# %%
missing_data= data.isnull().sum()
print("Missing Data:")
missing_data
# Out:
# Missing Data:
# CustomerID                  0
# Gender                      0
# Age                         0
# Income                      5
# City                        3
# Region                      0
# Frequency_of_Purchases      0
# Average_Purchase_Amount     0
# Customer_Lifespan_Months    0
# Purchase_Channel            0
# Date_of_Purchase            0
# Churn_Status                0
# dtype: int64

# %% [markdown]
# # Imputation task: filling the missing values with mean/median/mode strategy

# %%
 from sklearn.impute import SimpleImputer

# %%
imputer= SimpleImputer(strategy='median')
imputer.fit(data[['Income']])
data[['Income']]=imputer.transform(data[['Income']])

# %%
imputer_2=SimpleImputer(strategy='most_frequent')
imputer_2.fit(data[['City']])
data[['City']]=imputer_2.transform(data[['City']])

# %%
missing_data= data.isnull().sum()
print("Missing Data:")
missing_data
# Out:
# Missing Data:
# CustomerID                  0
# Gender                      0
# Age                         0
# Income                      0
# City                        0
# Region                      0
# Frequency_of_Purchases      0
# Average_Purchase_Amount     0
# Customer_Lifespan_Months    0
# Purchase_Channel            0
# Date_of_Purchase            0
# Churn_Status                0
# dtype: int64

# %% [markdown]
# # Data type correction: updating the correct data type for the correct  category

# %% [markdown]
# # Checking the data incosistencies first, deleting the unique inconsistent value then correcting the datatype

# %%
data.dtypes
# Out:
# CustomerID                   object
# Gender                       object
# Age                           int64
# Income                      float64
# City                         object
# Region                       object
# Frequency_of_Purchases        int64
# Average_Purchase_Amount     float64
# Customer_Lifespan_Months     object
# Purchase_Channel             object
# Date_of_Purchase             object
# Churn_Status                 object
# dtype: object

# %%
unique_values= data['Customer_Lifespan_Months'].unique()
unique_values
# Out:
# array([3, 4, 1, 2, 5, 'XXXX'], dtype=object)

# %%
data= data[data['Customer_Lifespan_Months']!='XXXX']

# %%
data['Customer_Lifespan_Months'].unique()
# Out:
# array([3, 4, 1, 2, 5], dtype=object)

# %%
data['Customer_Lifespan_Months']=data['Customer_Lifespan_Months'].astype(int)

# %%
unique_values= data['Date_of_Purchase'].unique()
unique_values
# Out:
# array(['2022-03-05', '2023-07-08', '2023-01-30', '2023-06-01',
#        '2022-09-23', '2022-11-30', '2023-07-20', '2022-05-24',
#        '2022-09-02', '2023-10-03', '2023-07-16', '2023-04-29',
#        '2023-02-13', '2023-05-21', '2023-03-30', '2022-01-02',
#        '2022-04-22', '2022-03-06', '2023-07-19', '2022-04-08',
#        '2023-06-08', '2023-12-24', '2023-07-15', '2023-07-11',
#        '2022-04-04', '2023-02-19', '2022-05-08', '2022-04-06',
#        '2023-04-04', '2022-11-05', '2022-08-16', '2023-08-05',
#        '2023-06-30', '2023-06-05', '2022-09-14', '2022-08-12',
#        '2023-12-02', '2023-03-07', '2022-10-26', '2022-05-31',
#        '2022-05-26', '2022-07-15', '2023-05-17', '2023-03-21',
#        '2022-12-29', '2022-12-07', '2023-09-19', '2022-12-05',
#        '2022-11-24', '2022-03-17', '2022-09-24', '2022-05-23',
#        '2023-12-29', '2023-09-26', '2022-11-07', '2022-02-11',
#        '2023-10-18', '2022-04-12', '2022-04-14', '2022-10-16',
#        '2022-07-28', '2023-09-09', '2023-06-18', '2023-11-16',
#        '2022-07-29', '2022-09-07', '2022-03-24', '2022-01-15',
#        '2023-05-04', '2023-07-28', '2023-12-22', '2022-11-20',
#        '2023-08-21', '2023-05-13', '2023-12-25', '2022-11-14',
#        '2022-12-08', '2023-09-18'], dtype=object)

# %%
data['Date_of_Purchase'].unique()
# Out:
# array(['2022-03-05', '2023-07-08', '2023-01-30', '2023-06-01',
#        '2022-09-23', '2022-11-30', '2023-07-20', '2022-05-24',
#        '2022-09-02', '2023-10-03', '2023-07-16', '2023-04-29',
#        '2023-02-13', '2023-05-21', '2023-03-30', '2022-01-02',
#        '2022-04-22', '2022-03-06', '2023-07-19', '2022-04-08',
#        '2023-06-08', '2023-12-24', '2023-07-15', '2023-07-11',
#        '2022-04-04', '2023-02-19', '2022-05-08', '2022-04-06',
#        '2023-04-04', '2022-11-05', '2022-08-16', '2023-08-05',
#        '2023-06-30', '2023-06-05', '2022-09-14', '2022-08-12',
#        '2023-12-02', '2023-03-07', '2022-10-26', '2022-05-31',
#        '2022-05-26', '2022-07-15', '2023-05-17', '2023-03-21',
#        '2022-12-29', '2022-12-07', '2023-09-19', '2022-12-05',
#        '2022-11-24', '2022-03-17', '2022-09-24', '2022-05-23',
#        '2023-12-29', '2023-09-26', '2022-11-07', '2022-02-11',
#        '2023-10-18', '2022-04-12', '2022-04-14', '2022-10-16',
#        '2022-07-28', '2023-09-09', '2023-06-18', '2023-11-16',
#        '2022-07-29', '2022-09-07', '2022-03-24', '2022-01-15',
#        '2023-05-04', '2023-07-28', '2023-12-22', '2022-11-20',
#        '2023-08-21', '2023-05-13', '2023-12-25', '2022-11-14',
#        '2022-12-08', '2023-09-18'], dtype=object)

# %%
data['Date_of_Purchase']=data['Date_of_Purchase'].astype('datetime64[ns]')

# %%
data.dtypes
# Out:
# CustomerID                          object
# Gender                              object
# Age                                  int64
# Income                             float64
# City                                object
# Region                              object
# Frequency_of_Purchases               int64
# Average_Purchase_Amount            float64
# Customer_Lifespan_Months             int64
# Purchase_Channel                    object
# Date_of_Purchase            datetime64[ns]
# Churn_Status                        object
# dtype: object

# %% [markdown]
# # Dealing with duplicate values in the data

# %%
duplicates= data.duplicated()
data[duplicates]
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 80       C021  Female   22  41743.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 80                       4                   54.599                         1
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 80           Online       2023-06-08           No

# %%
data.drop_duplicates(inplace=True)

# %%
duplicates= data.duplicated()
data[duplicates]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Income, City, Region, Frequency_of_Purchases, Average_Purchase_Amount, Customer_Lifespan_Months, Purchase_Channel, Date_of_Purchase, Churn_Status]
# Index: []

# %% [markdown]
# # Sorting and Arranging the data in a format

# %%
sorted_data=data.sort_values(by='Income', ascending=False)
sorted_data
# Out:
#    CustomerID  Gender  Age    Income         City     Region  \
# 55       C056  Female   29  107662.0      Houston  Northeast
# 22       C023  Female   41  105186.0  Los Angeles    Midwest
# 70       C071  Female   36  103264.0  Los Angeles  Northeast
# 32       C033  Female   31   98590.0      Houston       West
# 52       C053  Female   45   90860.0      Houston  Northeast
# ..        ...     ...  ...       ...          ...        ...
# 14       C015    Male   44   32500.0     New York  Northeast
# 49       C050  Female   39   29104.0      Houston    Midwest
# 10       C011  Female   53   27958.0  Los Angeles    Midwest
# 23       C024    Male   54   27660.0     New York    Midwest
# 50       C051  Female   19   15531.0      Houston    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 55                       3                   47.877                         1
# 22                      14                  137.697                         4
# 70                      11                  117.394                         3
# 32                       7                   76.114                         2
# 52                      10                  105.287                         3
# ..                     ...                      ...                       ...
# 14                       9                   96.473                         3
# 49                       7                   84.461                         2
# 10                      10                   98.449                         3
# 23                      12                  125.763                         3
# 50                      10                   97.782                         3
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 55         In-store       2022-02-11           No
# 22           Online       2023-07-15          Yes
# 70           Online       2023-12-22          Yes
# 32           Online       2023-06-30           No
# 52         In-store       2023-12-29          Yes
# ..              ...              ...          ...
# 14           Online       2023-03-30           No
# 49           Online       2022-03-17           No
# 10         In-store       2023-07-16          Yes
# 23           Online       2023-07-11          Yes
# 50         In-store       2022-09-24          Yes
#
# [79 rows x 12 columns]

# %%
sorted_data2=data.sort_values(by='Frequency_of_Purchases', ascending=True)
sorted_data2
# Out:
#    CustomerID  Gender  Age    Income         City     Region  \
# 2        C003    Male   17   63333.0     New York  Northeast
# 37       C038  Female   54   72700.0     New York       West
# 55       C056  Female   29  107662.0      Houston  Northeast
# 4        C005    Male   30   78889.0      Houston    Midwest
# 20       C021  Female   22   41743.0  Los Angeles  Northeast
# ..        ...     ...  ...       ...          ...        ...
# 75       C076    Male   44   59659.0      Houston    Midwest
# 38       C039    Male   43   51799.0      Houston       West
# 1        C002  Female   38   40881.0     New York       West
# 45       C046    Male   44   59154.0      Chicago       West
# 60       C061    Male   24   53080.0  Los Angeles       West
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 2                        1                   41.252                         1
# 37                       2                   46.456                         1
# 55                       3                   47.877                         1
# 4                        3                   52.763                         1
# 20                       4                   54.599                         1
# ..                     ...                      ...                       ...
# 75                      14                  134.540                         4
# 38                      14                  133.540                         4
# 1                       15                  157.640                         4
# 45                      15                  152.291                         4
# 60                      16                  193.046                         5
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 2            Online       2023-01-30           No
# 37         In-store       2023-03-07           No
# 55         In-store       2022-02-11           No
# 4            Online       2022-09-23           No
# 20           Online       2023-06-08           No
# ..              ...              ...          ...
# 75           Online       2023-12-25          Yes
# 38           Online       2022-10-26          Yes
# 1          In-store       2023-07-08          Yes
# 45           Online       2022-12-07          Yes
# 60         In-store       2022-07-28          Yes
#
# [79 rows x 12 columns]

# %% [markdown]
# # Data Slicing method

# %%
data.loc[0:4, 'CustomerID':'Region']
# Out:
#   CustomerID  Gender  Age   Income      City     Region
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest

# %%
data.iloc[0:5, 0:6]
# Out:
#   CustomerID  Gender  Age   Income      City     Region
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest

# %% [markdown]
# # Data Filtering Method

# %%
 male_data= data[data['Gender'] == 'Male']
male_data
# Out:
#    CustomerID Gender  Age   Income         City     Region  \
# 0        C001   Male   49  72504.0      Chicago  Northeast
# 2        C003   Male   17  63333.0     New York  Northeast
# 3        C004   Male   34  58030.0      Chicago    Midwest
# 4        C005   Male   30  78889.0      Houston    Midwest
# 5        C006   Male   52  76470.0      Chicago    Midwest
# 7        C008   Male   38  38401.0      Houston       West
# 8        C009   Male   44  73105.0  Los Angeles  Northeast
# 14       C015   Male   44  32500.0     New York  Northeast
# 15       C016   Male   37  59214.0      Houston    Midwest
# 17       C018   Male   39  86730.0     New York    Midwest
# 18       C019   Male   32  41111.0  Los Angeles       West
# 19       C020   Male   28  37050.0  Los Angeles    Midwest
# 21       C022   Male   26  78988.0      Chicago    Midwest
# 23       C024   Male   54  27660.0     New York    Midwest
# 24       C025   Male   27  45239.0  Los Angeles       West
# 33       C034   Male   53  78203.0      Houston  Northeast
# 34       C035   Male   28  50039.0     New York       West
# 35       C036   Male   23  43471.0     New York       West
# 38       C039   Male   43  51799.0      Houston       West
# 41       C042   Male   53  52616.0      Houston  Northeast
# 42       C043   Male   44  66344.0      Chicago    Midwest
# 44       C045   Male   22  46979.0      Houston       West
# 45       C046   Male   44  59154.0      Chicago       West
# 48       C049   Male   49  58036.0  Los Angeles       West
# 53       C054   Male   31  51243.0      Houston  Northeast
# 57       C058   Male   18  39995.0      Houston       West
# 59       C060   Male   35  82532.0      Houston    Midwest
# 60       C061   Male   24  53080.0  Los Angeles       West
# 62       C063   Male   39  47127.0     New York       West
# 63       C064   Male   30  58033.0      Houston       West
# 64       C065   Male   31  50889.0     New York       West
# 66       C067   Male   54  58033.0      Houston       West
# 69       C070   Male   36  58033.0      Chicago  Northeast
# 72       C073   Male   28  73631.0  Los Angeles       West
# 75       C076   Male   44  59659.0      Houston    Midwest
# 77       C078   Male   30  76887.0      Houston    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                       10                   98.241                         3
# 2                        1                   41.252                         1
# 3                        6                   67.329                         1
# 4                        3                   52.763                         1
# 5                       11                  117.012                         3
# 7                        6                   70.730                         2
# 8                       12                  124.887                         3
# 14                       9                   96.473                         3
# 15                      10                  108.902                         3
# 17                      11                  118.579                         3
# 18                      14                  133.229                         4
# 19                       6                   71.789                         2
# 21                       7                   76.826                         2
# 23                      12                  125.763                         3
# 24                      12                  127.888                         3
# 33                      12                  130.277                         3
# 34                       7                   75.568                         2
# 35                       5                   65.357                         1
# 38                      14                  133.540                         4
# 41                      11                  120.311                         3
# 42                      12                  130.562                         3
# 44                       8                   86.904                         2
# 45                      15                  152.291                         4
# 48                      12                  129.524                         3
# 53                       7                   73.408                         2
# 57                       7                   81.111                         2
# 59                       6                   68.405                         1
# 60                      16                  193.046                         5
# 62                      10                   96.553                         3
# 63                      10                  107.919                         3
# 64                       9                   94.469                         2
# 66                      12                  128.255                         3
# 69                       8                   85.832                         2
# 72                       9                   90.344                         2
# 75                      14                  134.540                         4
# 77                       7                   80.816                         2
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 0            Online       2022-03-05          Yes
# 2            Online       2023-01-30           No
# 3          In-store       2023-06-01           No
# 4            Online       2022-09-23           No
# 5            Online       2022-11-30          Yes
# 7            Online       2022-05-24           No
# 8            Online       2022-09-02          Yes
# 14           Online       2023-03-30           No
# 15           Online       2022-01-02          Yes
# 17           Online       2022-03-06          Yes
# 18           Online       2023-07-19          Yes
# 19           Online       2022-04-08           No
# 21         In-store       2023-12-24           No
# 23           Online       2023-07-11          Yes
# 24         In-store       2022-04-04          Yes
# 33         In-store       2023-06-05          Yes
# 34           Online       2022-09-14           No
# 35           Online       2022-08-12           No
# 38           Online       2022-10-26          Yes
# 41           Online       2022-07-15          Yes
# 42         In-store       2023-05-17          Yes
# 44           Online       2022-12-29           No
# 45           Online       2022-12-07          Yes
# 48           Online       2022-11-24          Yes
# 53           Online       2023-09-26           No
# 57         In-store       2022-04-12           No
# 59           Online       2022-10-16           No
# 60         In-store       2022-07-28          Yes
# 62           Online       2023-06-18          Yes
# 63         In-store       2023-11-16          Yes
# 64           Online       2022-07-29           No
# 66           Online       2022-03-24          Yes
# 69           Online       2023-07-28           No
# 72         In-store       2022-11-20           No
# 75           Online       2023-12-25          Yes
# 77           Online       2022-11-14           No

# %%
male_fre_data= male_data[male_data['Frequency_of_Purchases']>5]
male_fre_data
# Out:
#    CustomerID Gender  Age   Income         City     Region  \
# 0        C001   Male   49  72504.0      Chicago  Northeast
# 3        C004   Male   34  58030.0      Chicago    Midwest
# 5        C006   Male   52  76470.0      Chicago    Midwest
# 7        C008   Male   38  38401.0      Houston       West
# 8        C009   Male   44  73105.0  Los Angeles  Northeast
# 14       C015   Male   44  32500.0     New York  Northeast
# 15       C016   Male   37  59214.0      Houston    Midwest
# 17       C018   Male   39  86730.0     New York    Midwest
# 18       C019   Male   32  41111.0  Los Angeles       West
# 19       C020   Male   28  37050.0  Los Angeles    Midwest
# 21       C022   Male   26  78988.0      Chicago    Midwest
# 23       C024   Male   54  27660.0     New York    Midwest
# 24       C025   Male   27  45239.0  Los Angeles       West
# 33       C034   Male   53  78203.0      Houston  Northeast
# 34       C035   Male   28  50039.0     New York       West
# 38       C039   Male   43  51799.0      Houston       West
# 41       C042   Male   53  52616.0      Houston  Northeast
# 42       C043   Male   44  66344.0      Chicago    Midwest
# 44       C045   Male   22  46979.0      Houston       West
# 45       C046   Male   44  59154.0      Chicago       West
# 48       C049   Male   49  58036.0  Los Angeles       West
# 53       C054   Male   31  51243.0      Houston  Northeast
# 57       C058   Male   18  39995.0      Houston       West
# 59       C060   Male   35  82532.0      Houston    Midwest
# 60       C061   Male   24  53080.0  Los Angeles       West
# 62       C063   Male   39  47127.0     New York       West
# 63       C064   Male   30  58033.0      Houston       West
# 64       C065   Male   31  50889.0     New York       West
# 66       C067   Male   54  58033.0      Houston       West
# 69       C070   Male   36  58033.0      Chicago  Northeast
# 72       C073   Male   28  73631.0  Los Angeles       West
# 75       C076   Male   44  59659.0      Houston    Midwest
# 77       C078   Male   30  76887.0      Houston    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                       10                   98.241                         3
# 3                        6                   67.329                         1
# 5                       11                  117.012                         3
# 7                        6                   70.730                         2
# 8                       12                  124.887                         3
# 14                       9                   96.473                         3
# 15                      10                  108.902                         3
# 17                      11                  118.579                         3
# 18                      14                  133.229                         4
# 19                       6                   71.789                         2
# 21                       7                   76.826                         2
# 23                      12                  125.763                         3
# 24                      12                  127.888                         3
# 33                      12                  130.277                         3
# 34                       7                   75.568                         2
# 38                      14                  133.540                         4
# 41                      11                  120.311                         3
# 42                      12                  130.562                         3
# 44                       8                   86.904                         2
# 45                      15                  152.291                         4
# 48                      12                  129.524                         3
# 53                       7                   73.408                         2
# 57                       7                   81.111                         2
# 59                       6                   68.405                         1
# 60                      16                  193.046                         5
# 62                      10                   96.553                         3
# 63                      10                  107.919                         3
# 64                       9                   94.469                         2
# 66                      12                  128.255                         3
# 69                       8                   85.832                         2
# 72                       9                   90.344                         2
# 75                      14                  134.540                         4
# 77                       7                   80.816                         2
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 0            Online       2022-03-05          Yes
# 3          In-store       2023-06-01           No
# 5            Online       2022-11-30          Yes
# 7            Online       2022-05-24           No
# 8            Online       2022-09-02          Yes
# 14           Online       2023-03-30           No
# 15           Online       2022-01-02          Yes
# 17           Online       2022-03-06          Yes
# 18           Online       2023-07-19          Yes
# 19           Online       2022-04-08           No
# 21         In-store       2023-12-24           No
# 23           Online       2023-07-11          Yes
# 24         In-store       2022-04-04          Yes
# 33         In-store       2023-06-05          Yes
# 34           Online       2022-09-14           No
# 38           Online       2022-10-26          Yes
# 41           Online       2022-07-15          Yes
# 42         In-store       2023-05-17          Yes
# 44           Online       2022-12-29           No
# 45           Online       2022-12-07          Yes
# 48           Online       2022-11-24          Yes
# 53           Online       2023-09-26           No
# 57         In-store       2022-04-12           No
# 59           Online       2022-10-16           No
# 60         In-store       2022-07-28          Yes
# 62           Online       2023-06-18          Yes
# 63         In-store       2023-11-16          Yes
# 64           Online       2022-07-29           No
# 66           Online       2022-03-24          Yes
# 69           Online       2023-07-28           No
# 72         In-store       2022-11-20           No
# 75           Online       2023-12-25          Yes
# 77           Online       2022-11-14           No

# %%
data[(data['Customer_Lifespan_Months']>=2)&(data['Customer_Lifespan_Months']<=5)]
# Out:
#    CustomerID  Gender  Age   Income         City     Region  \
# 0        C001    Male   49  72504.0      Chicago  Northeast
# 1        C002  Female   38  40881.0     New York       West
# 5        C006    Male   52  76470.0      Chicago    Midwest
# 6        C007  Female   35  60349.0      Houston  Northeast
# 7        C008    Male   38  38401.0      Houston       West
# ..        ...     ...  ...      ...          ...        ...
# 72       C073    Male   28  73631.0  Los Angeles       West
# 75       C076    Male   44  59659.0      Houston    Midwest
# 77       C078    Male   30  76887.0      Houston    Midwest
# 78       C079  Female   42  56569.0     New York       West
# 79       C080  Female   26  43931.0  Los Angeles  Northeast
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                       10             9.824100e+01                         3
# 1                       15             1.576400e+02                         4
# 5                       11             1.170120e+02                         3
# 6                        9             9.554400e+01                         2
# 7                        6             7.073000e+01                         2
# ..                     ...                      ...                       ...
# 72                       9             9.034400e+01                         2
# 75                      14             1.345400e+02                         4
# 77                       7             8.081600e+01                         2
# 78                      11             1.342341e+07                         3
# 79                       9             9.153600e+01                         2
#
#    Purchase_Channel Date_of_Purchase Churn_Status
# 0            Online       2022-03-05          Yes
# 1          In-store       2023-07-08          Yes
# 5            Online       2022-11-30          Yes
# 6          In-store       2023-07-20           No
# 7            Online       2022-05-24           No
# ..              ...              ...          ...
# 72         In-store       2022-11-20           No
# 75           Online       2023-12-25          Yes
# 77           Online       2022-11-14           No
# 78         In-store       2022-12-08          Yes
# 79         In-store       2023-09-18           No
#
# [65 rows x 12 columns]

# %% [markdown]
# # Merging or Joining the data

# %%
 data2= pd.read_excel('performance_data.xlsx')
data2.head()
# Out:
#   CustomerID  Recency  Frequency_Score  Monetary_Score
# 0       C001        3                2               2
# 1       C002        3                3               3
# 2       C003        4                4               4
# 3       C004        2                2               2
# 4       C005        1                1               1

# %%
joined_data= pd.merge(data, data2, on= 'CustomerID', how='inner')
joined_data.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                      10                   98.241                         3
# 1                      15                  157.640                         4
# 2                       1                   41.252                         1
# 3                       6                   67.329                         1
# 4                       3                   52.763                         1
#
#   Purchase_Channel Date_of_Purchase Churn_Status  Recency  Frequency_Score  \
# 0           Online       2022-03-05          Yes        3                2
# 1         In-store       2023-07-08          Yes        3                3
# 2           Online       2023-01-30           No        4                4
# 3         In-store       2023-06-01           No        2                2
# 4           Online       2022-09-23           No        1                1
#
#    Monetary_Score
# 0               2
# 1               3
# 2               4
# 3               2
# 4               1

# %% [markdown]
# # Python for concatenation

# %%
joined_data.shape
# Out:
# (79, 15)

# %%
additional_data= pd.read_excel('additional_data.xlsx')
additional_data.head()
# Out:
#   CustomerID  Gender  Age  Income         City     Region  \
# 0       C081    Male   37   50728      Chicago       West
# 1       C082  Female   48   69629  Los Angeles    Midwest
# 2       C083    Male   28   29184      Chicago  Northeast
# 3       C084  Female   33   61265  Los Angeles       West
# 4       C085  Female   30   63130      Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                      11                   75.757                         2
# 1                       9                   78.433                         4
# 2                       7                   82.794                         3
# 3                      15                   88.490                         2
# 4                      13                  108.749                         3
#
#   Purchase_Channel Date_of_Purchase Churn_Status CustomerID.1  Recency  \
# 0         In-store       2023-09-10          Yes         C081        2
# 1         In-store       2023-07-15           No         C082        3
# 2           Online       2023-08-25          Yes         C083        3
# 3           Online       2022-10-22          Yes         C084        4
# 4           Online       2023-04-01          Yes         C085        4
#
#    Frequency_Score  Monetary_Score
# 0                2               1
# 1                4               4
# 2                1               2
# 3                1               3
# 4                4               1

# %%
final_data= pd.concat([joined_data, additional_data]).reset_index(drop=True)
final_data.tail()
# Out:
#    CustomerID  Gender  Age   Income     City     Region  \
# 94       C096    Male   32  18600.0  Chicago  Northeast
# 95       C097    Male   38  68525.0  Chicago       West
# 96       C098  Female   24  73538.0  Houston       West
# 97       C099  Female   20  47251.0  Chicago    Midwest
# 98       C100    Male   39  52054.0  Chicago    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 94                      12                  123.003                         4
# 95                      13                  106.526                         4
# 96                       3                  162.533                         1
# 97                       5                  145.404                         2
# 98                      14                   36.975                         2
#
#    Purchase_Channel Date_of_Purchase Churn_Status  Recency  Frequency_Score  \
# 94           Online       2022-02-03          Yes        4                2
# 95           Online       2023-09-20          Yes        4                3
# 96         In-store       2023-11-04          Yes        2                1
# 97         In-store       2022-09-24           No        4                3
# 98         In-store       2023-05-03           No        1                4
#
#     Monetary_Score CustomerID.1
# 94               3         C096
# 95               3         C097
# 96               1         C098
# 97               1         C099
# 98               4         C100

# %%
final_data= final_data.drop('CustomerID.1', axis=1)
final_data.tail()
# Out:
#    CustomerID  Gender  Age   Income     City     Region  \
# 94       C096    Male   32  18600.0  Chicago  Northeast
# 95       C097    Male   38  68525.0  Chicago       West
# 96       C098  Female   24  73538.0  Houston       West
# 97       C099  Female   20  47251.0  Chicago    Midwest
# 98       C100    Male   39  52054.0  Chicago    Midwest
#
#     Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 94                      12                  123.003                         4
# 95                      13                  106.526                         4
# 96                       3                  162.533                         1
# 97                       5                  145.404                         2
# 98                      14                   36.975                         2
#
#    Purchase_Channel Date_of_Purchase Churn_Status  Recency  Frequency_Score  \
# 94           Online       2022-02-03          Yes        4                2
# 95           Online       2023-09-20          Yes        4                3
# 96         In-store       2023-11-04          Yes        2                1
# 97         In-store       2022-09-24           No        4                3
# 98         In-store       2023-05-03           No        1                4
#
#     Monetary_Score
# 94               3
# 95               3
# 96               1
# 97               1
# 98               4

# %%
 final_data.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                      10                   98.241                         3
# 1                      15                  157.640                         4
# 2                       1                   41.252                         1
# 3                       6                   67.329                         1
# 4                       3                   52.763                         1
#
#   Purchase_Channel     Date_of_Purchase Churn_Status  Recency  \
# 0           Online  2022-03-05 00:00:00          Yes        3
# 1         In-store  2023-07-08 00:00:00          Yes        3
# 2           Online  2023-01-30 00:00:00           No        4
# 3         In-store  2023-06-01 00:00:00           No        2
# 4           Online  2022-09-23 00:00:00           No        1
#
#    Frequency_Score  Monetary_Score
# 0                2               2
# 1                3               3
# 2                4               4
# 3                2               2
# 4                1               1

# %% [markdown]
# # Frequency Analysis:

# %%
freq_purchase_channel= final_data['Purchase_Channel'].value_counts()
freq_purchase_channel
# Out:
# Purchase_Channel
# Online      65
# In-store    34
# Name: count, dtype: int64

# %% [markdown]
# # Percentage Analysis:

# %%
perc_purchase_channel= prec_purchase_channel=freq_purchase_channel/len(final_data['Purchase_Channel'])*100                                                               
perc_purchase_channel
# Out:
# Purchase_Channel
# Online      65.656566
# In-store    34.343434
# Name: count, dtype: float64

# %%
round(final_data.describe())
# Out:
#         Age    Income  Frequency_of_Purchases  Average_Purchase_Amount  \
# count  99.0      99.0                    99.0                     99.0
# mean   35.0   58115.0                     9.0                 135687.0
# std    10.0   18618.0                     3.0                1349094.0
# min    17.0   15531.0                     1.0                     37.0
# 25%    28.0   45724.0                     7.0                     76.0
# 50%    35.0   58033.0                    10.0                     98.0
# 75%    42.0   71484.0                    12.0                    121.0
# max    54.0  107662.0                    16.0               13423412.0
#
#        Customer_Lifespan_Months  Recency  Frequency_Score  Monetary_Score
# count                      99.0     99.0             99.0            99.0
# mean                        3.0      3.0              3.0             3.0
# std                         1.0      1.0              1.0             1.0
# min                         0.0      1.0              1.0             1.0
# 25%                         2.0      2.0              2.0             2.0
# 50%                         3.0      3.0              3.0             3.0
# 75%                         3.0      4.0              4.0             4.0
# max                         5.0      4.0              4.0             4.0

# %%
final_data['Average_Purchase_Amount'].unique()
# Out:
# array([9.8241000e+01, 1.5764000e+02, 4.1252000e+01, 6.7329000e+01,
#        5.2763000e+01, 1.1701200e+02, 9.5544000e+01, 7.0730000e+01,
#        1.2488700e+02, 1.0814800e+02, 9.8449000e+01, 8.5430000e+01,
#        1.0347600e+02, 1.1119400e+02, 9.6473000e+01, 1.0890200e+02,
#        1.3192700e+02, 1.1857900e+02, 1.3322900e+02, 7.1789000e+01,
#        5.4599000e+01, 7.6826000e+01, 1.3769700e+02, 1.2576300e+02,
#        1.2788800e+02, 5.8264000e+01, 1.3717100e+02, 1.0294600e+02,
#        1.2716500e+02, 1.3203500e+02, 1.2140200e+02, 1.2092100e+02,
#        7.6114000e+01, 1.3027700e+02, 7.5568000e+01, 6.5357000e+01,
#        8.5129000e+01, 4.6456000e+01, 1.3354000e+02, 7.8414000e+01,
#        1.2518500e+02, 1.2031100e+02, 1.3056200e+02, 8.8419000e+01,
#        8.6904000e+01, 1.5229100e+02, 1.1097000e+02, 8.5194000e+01,
#        1.2952400e+02, 8.4461000e+01, 9.7782000e+01, 6.8116000e+01,
#        1.0528700e+02, 7.3408000e+01, 5.9388000e+01, 4.7877000e+01,
#        9.3780000e+01, 8.1111000e+01, 8.6207000e+01, 6.8405000e+01,
#        1.9304600e+02, 7.8158000e+01, 9.6553000e+01, 1.0791900e+02,
#        9.4469000e+01, 1.1272200e+02, 1.2825500e+02, 1.0108800e+02,
#        9.6442000e+01, 8.5832000e+01, 1.1739400e+02, 6.1191000e+01,
#        9.0344000e+01, 6.5224000e+01, 5.7984000e+01, 1.3454000e+02,
#        8.0816000e+01, 1.3423412e+07, 9.1536000e+01, 7.5757000e+01,
#        7.8433000e+01, 8.2794000e+01, 8.8490000e+01, 1.0874900e+02,
#        1.0218600e+02, 9.9443000e+01, 1.0300100e+02, 1.1284200e+02,
#        6.8806000e+01, 1.0873700e+02, 9.9827000e+01, 7.0519000e+01,
#        7.5875000e+01, 6.4054000e+01, 1.2300300e+02, 1.0652600e+02,
#        1.6253300e+02, 1.4540400e+02, 3.6975000e+01])

# %%
final_data['Average_Purchase_Amount'].dtype
final_data['Average_Purchase_Amount'] = pd.to_numeric(
    final_data['Average_Purchase_Amount'], errors='coerce'
)

# %%
final_data = final_data[final_data['Average_Purchase_Amount'] < 10000000.0]

# %%
round(final_data.describe())
# Out:
#         Age    Income  Frequency_of_Purchases  Average_Purchase_Amount  \
# count  98.0      98.0                    98.0                     98.0
# mean   35.0   58131.0                     9.0                     98.0
# std    10.0   18713.0                     3.0                     29.0
# min    17.0   15531.0                     1.0                     37.0
# 25%    28.0   45482.0                     7.0                     76.0
# 50%    35.0   58033.0                    10.0                     97.0
# 75%    42.0   71994.0                    12.0                    120.0
# max    54.0  107662.0                    16.0                    193.0
#
#        Customer_Lifespan_Months  Recency  Frequency_Score  Monetary_Score
# count                      98.0     98.0             98.0            98.0
# mean                        3.0      3.0              3.0             3.0
# std                         1.0      1.0              1.0             1.0
# min                         0.0      1.0              1.0             1.0
# 25%                         2.0      2.0              2.0             2.0
# 50%                         3.0      3.0              3.0             3.0
# 75%                         3.0      4.0              4.0             4.0
# max                         5.0      4.0              4.0             4.0

# %% [markdown]
# # Group-By Analysis:

# %%
city_purchase_amount= final_data.groupby('City')['Average_Purchase_Amount'].median()
city_purchase_amount
# Out:
# City
# Chicago        102.1860
# Houston         87.6615
# Los Angeles    100.7250
# New York        94.4690
# Name: Average_Purchase_Amount, dtype: float64

# %% [markdown]
# # PIVOT Table Analysis:

# %%
pivot_table= final_data.pivot_table(index= 'Churn_Status', values =['Recency', 'Frequency_Score', 'Monetary_Score'], aggfunc= {'Recency':'mean', 'Frequency_Score':'mean', 'Monetary_Score':'mean', 'Churn_Status':'count'})

# %%
pivot_table
# Out:
#               Churn_Status  Frequency_Score  Monetary_Score   Recency
# Churn_Status
# No                      43         2.744186        2.558140  2.720930
# Yes                     55         2.509091        2.509091  2.618182

# %%
pivot_table= pivot_table.rename(columns={'Churn_Status':'Freq_Churn', 'Recency':'Mean_Frequency', 'Frequency_Score':'Mean_FS', 'Monetary_Score':'Mean_MS'})

# %%
pivot_table
# Out:
#               Freq_Churn   Mean_FS   Mean_MS  Mean_Frequency
# Churn_Status
# No                    43  2.744186  2.558140        2.720930
# Yes                   55  2.509091  2.509091        2.618182

# %% [markdown]
# # Cross-Tab Analysis

# %%
cross_tab= pd.crosstab(final_data['City'], final_data['Churn_Status'])
cross_tab
# Out:
# Churn_Status  No  Yes
# City
# Chicago        8   17
# Houston       16   16
# Los Angeles   10   14
# New York       9    8

# %% [markdown]
# # Creating Bar Chart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Plotting Functions: .figure(), .plot(), .title(), .xlabel(), .ylabel(), .show()

# %%
plt.figure(figsize=(10, 6))
freq_purchase_channel.plot(kind='bar')
plt.title('Frequency Analysis of purchases via channels')
plt.xlabel('Purchase channels')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Purchase_Channel', data= final_data)
plt.title('Frequency Analysis of purchases via channels')
plt.xlabel('Purchase channels')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Stacked Bar Chart Analysis:

# %%
plt.figure(figsize=(10,6))
cross_tab.plot(kind='bar', stacked= True)
plt.title('Customers churned by Cities')
plt.xlabel('City')
plt.ylabel('Frequencies')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='City', hue='Churn_Status', data= final_data)
plt.title('Customers churned by Cities')
plt.xlabel('City')
plt.ylabel('Frequencies')
plt.show()

# %% [markdown]
# # Pie Chart analysis:

# %%
plt.figure(figsize=(10, 6))
perc_purchase_channel.plot(kind='pie', autopct='%1.1f%%')
plt.title('Precentage of purchase channels')
plt.ylabel(' ')
plt.show()

# %% [markdown]
# # Line Chart Analysis:

# %%
plt.figure(figsize=(10, 6))
city_purchase_amount.plot(kind='line', marker='o')
plt.title('Average purchase amount by Cities')
plt.xlabel('Cities')
plt.ylabel('Average Purchase Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x= 'City', y= 'Average_Purchase_Amount', data= final_data, marker='o')
plt.title('Average purchase amount by Cities')
plt.xlabel('Cities')
plt.ylabel('Average Purchase Amount')
plt.show()

# %% [markdown]
# # Histogram Analysis:

# %%
plt.figure(figsize=(10,6))
final_data['Average_Purchase_Amount'].plot(kind='hist', bins= 5)
plt.title('Distribution of Average Purchse Amount')
plt.xlabel('Average Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(final_data['Average_Purchase_Amount'], bins= 5)
plt.title('Distribution of Average Purchse Amount')
plt.xlabel('Average Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Scatter Plot Analysis:

# %%
plt.figure(figsize=(10, 6))
plt.scatter(final_data['Frequency_of_Purchases'], final_data['Average_Purchase_Amount'])
plt.title('Relationship between FP and APA')
plt.xlabel('Frequency_of_Purchases')
plt.ylabel('Average Purchase Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='Frequency_of_Purchases', y= 'Average_Purchase_Amount', data= final_data)
plt.title('Relationship between FP and APA')
plt.xlabel('Frequency_of_Purchases')
plt.ylabel('Average Purchase Amount')
plt.show()

# %% [markdown]
# # Heatmap Analysis:

# %%
correl= final_data.corr(numeric_only=True)
correl
# Out:
#                                Age    Income  Frequency_of_Purchases  \
# Age                       1.000000  0.109923                0.300892
# Income                    0.109923  1.000000               -0.021973
# Frequency_of_Purchases    0.300892 -0.021973                1.000000
# Average_Purchase_Amount   0.170165  0.023373                0.703991
# Customer_Lifespan_Months  0.333779  0.067700                0.761521
# Recency                  -0.047760  0.178459               -0.063353
# Frequency_Score          -0.006453  0.163098               -0.064682
# Monetary_Score            0.065196  0.162363               -0.065994
#
#                           Average_Purchase_Amount  Customer_Lifespan_Months  \
# Age                                      0.170165                  0.333779
# Income                                   0.023373                  0.067700
# Frequency_of_Purchases                   0.703991                  0.761521
# Average_Purchase_Amount                  1.000000                  0.690196
# Customer_Lifespan_Months                 0.690196                  1.000000
# Recency                                 -0.028565                 -0.072544
# Frequency_Score                         -0.145007                 -0.013246
# Monetary_Score                          -0.190808                 -0.001114
#
#                            Recency  Frequency_Score  Monetary_Score
# Age                      -0.047760        -0.006453        0.065196
# Income                    0.178459         0.163098        0.162363
# Frequency_of_Purchases   -0.063353        -0.064682       -0.065994
# Average_Purchase_Amount  -0.028565        -0.145007       -0.190808
# Customer_Lifespan_Months -0.072544        -0.013246       -0.001114
# Recency                   1.000000         0.760652        0.743275
# Frequency_Score           0.760652         1.000000        0.819151
# Monetary_Score            0.743275         0.819151        1.000000

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(correl, annot= True)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # Box plot Analysis:

# %%
plt.figure(figsize=(10, 8))
sns.boxplot(x='Average_Purchase_Amount',y= 'Churn_Status', data= final_data)
plt.title('Box Plot of Average Purchase Amount')
plt.xlabel('Average Purchase Amount')
plt.show()

# %% [markdown]
# # Data Transformation

# %% [markdown]
# # KDE Plot Analysis:

# %%
numeric_columns= ['Age', 'Average_Purchase_Amount']
fig, axes= plt.subplots(1, 2, figsize=( 12, 8))
for index, column in enumerate(numeric_columns):
    sns.kdeplot(final_data[column], ax= axes[index])
    axes[index].set_title(f'KDE plot of {column}')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Shapiro-Wilk Test

# %%
from scipy.stats import shapiro
shapiro_results= {}

for column in numeric_columns:
    stat, p_value= shapiro(final_data[column])
    shapiro_results[column]= round(p_value, 3)

shapiro_results
# Out:
# {'Age': np.float64(0.037), 'Average_Purchase_Amount': np.float64(0.487)}

# %% [markdown]
# # Python for Data Transformation

# %% [markdown]
# ## Square Root Transformation distribution

# %%
import numpy as np

# %%
def sqrt_transformation(data, column_name):
    data[f'{column_name}_sqrt']=np.sqrt(data[column_name])
    stat, p_value= shapiro(data[f'{column_name}_sqrt'])
    kdeplot= sns.kdeplot(data[f'{column_name}_sqrt'])

    print(kdeplot)
    print('P value: ', p_value)

# %%
sqrt_transformation(final_data,'Age')
# Out:
# Axes(0.125,0.11;0.775x0.77)
# P value:  0.09854088997154391

# %%
final_data.head()
# Out:
#   CustomerID  Gender  Age   Income      City     Region  \
# 0       C001    Male   49  72504.0   Chicago  Northeast
# 1       C002  Female   38  40881.0  New York       West
# 2       C003    Male   17  63333.0  New York  Northeast
# 3       C004    Male   34  58030.0   Chicago    Midwest
# 4       C005    Male   30  78889.0   Houston    Midwest
#
#    Frequency_of_Purchases  Average_Purchase_Amount  Customer_Lifespan_Months  \
# 0                      10                   98.241                         3
# 1                      15                  157.640                         4
# 2                       1                   41.252                         1
# 3                       6                   67.329                         1
# 4                       3                   52.763                         1
#
#   Purchase_Channel     Date_of_Purchase Churn_Status  Recency  \
# 0           Online  2022-03-05 00:00:00          Yes        3
# 1         In-store  2023-07-08 00:00:00          Yes        3
# 2           Online  2023-01-30 00:00:00           No        4
# 3         In-store  2023-06-01 00:00:00           No        2
# 4           Online  2022-09-23 00:00:00           No        1
#
#    Frequency_Score  Monetary_Score  Age_sqrt
# 0                2               2  7.000000
# 1                3               3  6.164414
# 2                4               4  4.123106
# 3                2               2  5.830952
# 4                1               1  5.477226

# %% [markdown]
# ## Log transformation Distribution

# %%
def log_transformation(data, column_name):
    data[f'{column_name}_log']= np.log(data[column_name])
    stat, p_value= shapiro(data[f'{column_name}_log'])
    kdeplot= sns.kdeplot(data[f'{column_name}_log'])

    print(kdeplot)
    print('P_value: ', p_value)

# %%
log_transformation(final_data, 'Age')
# Out:
# Axes(0.125,0.11;0.775x0.77)
# P_value:  0.03301636122262527

# %% [markdown]
# ## BoxCox Transformation

# %%
from scipy.stats import boxcox
def boxcox_transformation(data, column_name):
    transformed_data, _= boxcox(data[column_name])
    data[f'{column_name}_boxcox']= transformed_data
    stat, p_value= shapiro(data[f'{column_name}_boxcox'])
    kdeplot= sns.kdeplot(data[f'{column_name}_boxcox'])

    print(kdeplot)
    print('P value:', p_value)

# %%
boxcox_transformation(final_data, 'Age')
# Out:
# Axes(0.125,0.11;0.775x0.77)
# P value: 0.0980634621204454

# %% [markdown]
# # Statistical Analysis

# %% [markdown]
# ## Independent Sample t-test

# %%
preprocessed_data = final_data.drop(['Age', 'Age_boxcox'], axis = 1)
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                      10
# 1       C002  Female  40881.0  New York       West                      15
# 2       C003    Male  63333.0  New York  Northeast                       1
# 3       C004    Male  58030.0   Chicago    Midwest                       6
# 4       C005    Male  78889.0   Houston    Midwest                       3
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#       Date_of_Purchase Churn_Status  Recency  Frequency_Score  Monetary_Score  \
# 0  2022-03-05 00:00:00          Yes        3                2               2
# 1  2023-07-08 00:00:00          Yes        3                3               3
# 2  2023-01-30 00:00:00           No        4                4               4
# 3  2023-06-01 00:00:00           No        2                2               2
# 4  2022-09-23 00:00:00           No        1                1               1
#
#    Age_sqrt   Age_log
# 0  7.000000  3.891820
# 1  6.164414  3.637586
# 2  4.123106  2.833213
# 3  5.830952  3.526361
# 4  5.477226  3.401197

# %%
from scipy import stats

hypothesized_mean= 68

t_stat, p_value= stats.ttest_1samp(preprocessed_data['Average_Purchase_Amount'], hypothesized_mean)
print("P value:", p_value)

if p_value<0.05:
    print('Reject the null hypothesis')
else:
    print('Fail to reject the null hypothesis')
# Out:
# P value: 3.765882799621164e-17
# Reject the null hypothesis

# %%
churned_customers= final_data.query('Churn_Status=="Yes"')['Average_Purchase_Amount']
existing_customers= final_data.query('Churn_Status=="No"')['Average_Purchase_Amount']

t_stat, p_value= stats.ttest_ind(churned_customers, existing_customers)
print("P value:", p_value)

if p_value<0.05:
    print('Reject the null hypothesis')
else:
    print('Fail to  reject the null hypothesis')
# Out:
# P value: 1.077550720319448e-13
# Reject the null hypothesis

# %%
churned_customers.mean()
# Out:
# np.float64(114.96134545454547)

# %%
existing_customers.mean()
# Out:
# np.float64(76.42560465116279)

# %% [markdown]
#  # Analysis of Variance

# %%
stat, p_value= shapiro(preprocessed_data['Frequency_of_Purchases'])
print(p_value)
# Out:
# 0.11246168308148519

# %%
chicago_cust= preprocessed_data.query('City=="Chicago"')['Frequency_of_Purchases']
newyork_cust= preprocessed_data.query('City=="New York"')['Frequency_of_Purchases']
houston_cust= preprocessed_data.query('City=="Houston"')['Frequency_of_Purchases']
losangeles_cust= preprocessed_data.query('City=="Los Angeles"')['Frequency_of_Purchases']

Test_stat, p_value= stats.f_oneway(chicago_cust, newyork_cust, houston_cust, losangeles_cust)
print("P Value:", p_value)

if p_value < 0.05:
    print('Reject the null hypothesis')
else:
    print('Fail to reject the null hypothesis')
# Out:
# P Value: 0.0937561908706892
# Fail to reject the null hypothesis

# %%
from scipy.stats import levene

stats, p_value= levene(chicago_cust, newyork_cust, houston_cust, losangeles_cust)
print('P value: ', p_value)
# Out:
# P value:  0.500791837582151

# %% [markdown]
# # Chi-Square Test for Independence

# %%
from scipy.stats import chi2_contingency

# %%
cross_tab= pd.crosstab(preprocessed_data['Purchase_Channel'], preprocessed_data['Region'])

chi2, p_value, dof, expected= chi2_contingency(cross_tab)
print("P value: ", p_value)

if p_value < 0.05:
    print('Reject the null hypothesis')
else:
    print('Fail to reject the null hypothesis')
# Out:
# P value:  0.628361041713461
# Fail to reject the null hypothesis

# %% [markdown]
# # Pearson Correlation test

# %%
plt.figure(figsize= (10, 6))
sns.regplot(x='Frequency_of_Purchases', y='Average_Purchase_Amount', data= preprocessed_data)
plt.title('Linearity b/w FP and APA')
plt.xlabel('FP')
plt.ylabel('APA')
plt.show()

# %%
from scipy.stats import pearsonr

purchase_frequency= preprocessed_data['Frequency_of_Purchases']
purchase_amount= preprocessed_data['Average_Purchase_Amount']

corr, p_value= pearsonr(purchase_frequency, purchase_amount)
print("Correlation coefficient: ", corr)
print("P value: ", p_value)

if p_value < 0.05:
    print('Reject the null hypothesis')
else:
    print('Fail to reject the null hypothesis')
# Out:
# Correlation coefficient:  0.7039911501130026
# P value:  6.176786543554943e-16
# Reject the null hypothesis

# %% [markdown]
# # Linear Regression Model

# %%
import statsmodels.api as sm

x= preprocessed_data['Frequency_of_Purchases']
y= preprocessed_data['Average_Purchase_Amount']

x_constant= sm.add_constant(x)
model= sm.OLS(y,x_constant).fit()

print(model.summary())
# Out:
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Average_Purchase_Amount   R-squared:                       0.496
# Model:                                 OLS   Adj. R-squared:                  0.490
# Method:                      Least Squares   F-statistic:                     94.33
# Date:                     Sun, 22 Feb 2026   Prob (F-statistic):           6.18e-16
# Time:                             19:22:28   Log-Likelihood:                -435.04
# No. Observations:                       98   AIC:                             874.1
# Df Residuals:                           96   BIC:                             879.3
# Df Model:                                1
# Covariance Type:                 nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     39.0765      6.423      6.084      0.000      26.328      51.825
# Frequency_of_Purchases     6.2551      0.644      9.712      0.000       4.977       7.533
# ==============================================================================
# Omnibus:                       43.074   Durbin-Watson:                   1.673
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              477.367
# Skew:                           0.929   Prob(JB):                    2.19e-104
# Kurtosis:                      13.651   Cond. No.                         30.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
predicted_APA= 39.0765 + (6.2551*70)
predicted_APA
# Out:
# 476.9335

# %% [markdown]
# # Generating New Features (Feature Engineering)

# %%
preprocessed_data['Customer_value']= preprocessed_data['Frequency_of_Purchases']= preprocessed_data['Average_Purchase_Amount']

# %%
preprocessed_data['CLV']= preprocessed_data['Customer_value']= preprocessed_data['Customer_Lifespan_Months']

# %%
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#       Date_of_Purchase Churn_Status  Recency  Frequency_Score  Monetary_Score  \
# 0  2022-03-05 00:00:00          Yes        3                2               2
# 1  2023-07-08 00:00:00          Yes        3                3               3
# 2  2023-01-30 00:00:00           No        4                4               4
# 3  2023-06-01 00:00:00           No        2                2               2
# 4  2022-09-23 00:00:00           No        1                1               1
#
#    Age_sqrt   Age_log  Customer_value  CLV
# 0  7.000000  3.891820               3    3
# 1  6.164414  3.637586               4    4
# 2  4.123106  2.833213               1    1
# 3  5.830952  3.526361               1    1
# 4  5.477226  3.401197               1    1

# %% [markdown]
# # Extracting Data Elements

# %%
preprocessed_data['Date_of_Purchase']= preprocessed_data['Date_of_Purchase'].astype('datetime64[ns]')

preprocessed_data['Year']= preprocessed_data['Date_of_Purchase'].dt.year
preprocessed_data['Month']= preprocessed_data['Date_of_Purchase'].dt.month
preprocessed_data['Date']= preprocessed_data['Date_of_Purchase'].dt.day

# %%
preprocessed_data= preprocessed_data.drop('Date_of_Purchase', axis= 1)
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#   Churn_Status  Recency  Frequency_Score  Monetary_Score  Age_sqrt   Age_log  \
# 0          Yes        3                2               2  7.000000  3.891820
# 1          Yes        3                3               3  6.164414  3.637586
# 2           No        4                4               4  4.123106  2.833213
# 3           No        2                2               2  5.830952  3.526361
# 4           No        1                1               1  5.477226  3.401197
#
#    Customer_value  CLV  Year  Month  Date
# 0               3    3  2022      3     5
# 1               4    4  2023      7     8
# 2               1    1  2023      1    30
# 3               1    1  2023      6     1
# 4               1    1  2022      9    23

# %% [markdown]
# # Encoding Feature

# %%
from sklearn.preprocessing import LabelEncoder

encoder= LabelEncoder()
preprocessed_data['Churn_Status']= encoder.fit_transform(preprocessed_data['Churn_Status'])
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#    Churn_Status  Recency  Frequency_Score  Monetary_Score  Age_sqrt   Age_log  \
# 0             1        3                2               2  7.000000  3.891820
# 1             1        3                3               3  6.164414  3.637586
# 2             0        4                4               4  4.123106  2.833213
# 3             0        2                2               2  5.830952  3.526361
# 4             0        1                1               1  5.477226  3.401197
#
#    Customer_value  CLV  Year  Month  Date
# 0               3    3  2022      3     5
# 1               4    4  2023      7     8
# 2               1    1  2023      1    30
# 3               1    1  2023      6     1
# 4               1    1  2022      9    23

# %% [markdown]
# # Binning Feature

# %%
preprocessed_data['engagement_level']= pd.cut(preprocessed_data['Customer_Lifespan_Months'], 
                                              bins= [0,2,3,5], 
                                              labels= ['Low engaged', 'Moderately engaged', 'Highly engaged'], 
                                              include_lowest= True)
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#    Churn_Status  ...  Frequency_Score  Monetary_Score  Age_sqrt   Age_log  \
# 0             1  ...                2               2  7.000000  3.891820
# 1             1  ...                3               3  6.164414  3.637586
# 2             0  ...                4               4  4.123106  2.833213
# 3             0  ...                2               2  5.830952  3.526361
# 4             0  ...                1               1  5.477226  3.401197
#
#    Customer_value  CLV  Year  Month  Date    engagement_level
# 0               3    3  2022      3     5  Moderately engaged
# 1               4    4  2023      7     8      Highly engaged
# 2               1    1  2023      1    30         Low engaged
# 3               1    1  2023      6     1         Low engaged
# 4               1    1  2022      9    23         Low engaged
#
# [5 rows x 21 columns]

# %% [markdown]
# # Mapping Feature

# %%
mapping= {'Low engaged': 1, 'Moderately engaged:': 2, 'Highly engaged': 3}
preprocessed_data['engagement_level']= preprocessed_data['engagement_level'].map(mapping)
preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#    Churn_Status  ...  Frequency_Score  Monetary_Score  Age_sqrt   Age_log  \
# 0             1  ...                2               2  7.000000  3.891820
# 1             1  ...                3               3  6.164414  3.637586
# 2             0  ...                4               4  4.123106  2.833213
# 3             0  ...                2               2  5.830952  3.526361
# 4             0  ...                1               1  5.477226  3.401197
#
#    Customer_value  CLV  Year  Month  Date  engagement_level
# 0               3    3  2022      3     5               NaN
# 1               4    4  2023      7     8               3.0
# 2               1    1  2023      1    30               1.0
# 3               1    1  2023      6     1               1.0
# 4               1    1  2022      9    23               1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Generating Dummies

# %%
preprocessed_data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Income', 'City', 'Region',
#        'Frequency_of_Purchases', 'Average_Purchase_Amount',
#        'Customer_Lifespan_Months', 'Purchase_Channel', 'Churn_Status',
#        'Recency', 'Frequency_Score', 'Monetary_Score', 'Age_sqrt', 'Age_log',
#        'Customer_value', 'CLV', 'Year', 'Month', 'Date', 'engagement_level'],
#       dtype='object')

# %%
dummies= pd.get_dummies(preprocessed_data[['Gender', 'City', 'Region', 'Purchase_Channel']])
processed_data= pd.concat([preprocessed_data, dummies], axis=1)

preprocessed_data.head()
# Out:
#   CustomerID  Gender   Income      City     Region  Frequency_of_Purchases  \
# 0       C001    Male  72504.0   Chicago  Northeast                  98.241
# 1       C002  Female  40881.0  New York       West                 157.640
# 2       C003    Male  63333.0  New York  Northeast                  41.252
# 3       C004    Male  58030.0   Chicago    Midwest                  67.329
# 4       C005    Male  78889.0   Houston    Midwest                  52.763
#
#    Average_Purchase_Amount  Customer_Lifespan_Months Purchase_Channel  \
# 0                   98.241                         3           Online
# 1                  157.640                         4         In-store
# 2                   41.252                         1           Online
# 3                   67.329                         1         In-store
# 4                   52.763                         1           Online
#
#    Churn_Status  ...  Frequency_Score  Monetary_Score  Age_sqrt   Age_log  \
# 0             1  ...                2               2  7.000000  3.891820
# 1             1  ...                3               3  6.164414  3.637586
# 2             0  ...                4               4  4.123106  2.833213
# 3             0  ...                2               2  5.830952  3.526361
# 4             0  ...                1               1  5.477226  3.401197
#
#    Customer_value  CLV  Year  Month  Date  engagement_level
# 0               3    3  2022      3     5               NaN
# 1               4    4  2023      7     8               3.0
# 2               1    1  2023      1    30               1.0
# 3               1    1  2023      6     1               1.0
# 4               1    1  2022      9    23               1.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Feature Selection

# %%
processed_data.columns
# Out:
# Index(['CustomerID', 'Gender', 'Income', 'City', 'Region',
#        'Frequency_of_Purchases', 'Average_Purchase_Amount',
#        'Customer_Lifespan_Months', 'Purchase_Channel', 'Churn_Status',
#        'Recency', 'Frequency_Score', 'Monetary_Score', 'Age_sqrt', 'Age_log',
#        'Customer_value', 'CLV', 'Year', 'Month', 'Date', 'engagement_level',
#        'Gender_Female', 'Gender_Male', 'City_Chicago', 'City_Houston',
#        'City_Los Angeles', 'City_New York', 'Region_Midwest',
#        'Region_Northeast', 'Region_West', 'Purchase_Channel_In-store',
#        'Purchase_Channel_Online'],
#       dtype='object')

# %%
x_reg= processed_data.drop(['CustomerID', 'Gender', 'City', 'Region', 'Purchase_Channel', 'CLV'], axis= 1)
y_reg= processed_data['CLV']

# %%
x_reg
# Out:
#      Income  Frequency_of_Purchases  Average_Purchase_Amount  \
# 0   72504.0                  98.241                   98.241
# 1   40881.0                 157.640                  157.640
# 2   63333.0                  41.252                   41.252
# 3   58030.0                  67.329                   67.329
# 4   78889.0                  52.763                   52.763
# ..      ...                     ...                      ...
# 94  18600.0                 123.003                  123.003
# 95  68525.0                 106.526                  106.526
# 96  73538.0                 162.533                  162.533
# 97  47251.0                 145.404                  145.404
# 98  52054.0                  36.975                   36.975
#
#     Customer_Lifespan_Months  Churn_Status  Recency  Frequency_Score  \
# 0                          3             1        3                2
# 1                          4             1        3                3
# 2                          1             0        4                4
# 3                          1             0        2                2
# 4                          1             0        1                1
# ..                       ...           ...      ...              ...
# 94                         4             1        4                2
# 95                         4             1        4                3
# 96                         1             1        2                1
# 97                         2             0        4                3
# 98                         2             0        1                4
#
#     Monetary_Score  Age_sqrt   Age_log  ...  Gender_Male  City_Chicago  \
# 0                2  7.000000  3.891820  ...         True          True
# 1                3  6.164414  3.637586  ...        False         False
# 2                4  4.123106  2.833213  ...         True         False
# 3                2  5.830952  3.526361  ...         True          True
# 4                1  5.477226  3.401197  ...         True         False
# ..             ...       ...       ...  ...          ...           ...
# 94               3  5.656854  3.465736  ...         True          True
# 95               3  6.164414  3.637586  ...         True          True
# 96               1  4.898979  3.178054  ...        False         False
# 97               1  4.472136  2.995732  ...        False          True
# 98               4  6.244998  3.663562  ...         True          True
#
#     City_Houston  City_Los Angeles  City_New York  Region_Midwest  \
# 0          False             False          False           False
# 1          False             False           True           False
# 2          False             False           True           False
# 3          False             False          False            True
# 4           True             False          False            True
# ..           ...               ...            ...             ...
# 94         False             False          False           False
# 95         False             False          False           False
# 96          True             False          False           False
# 97         False             False          False            True
# 98         False             False          False            True
#
#     Region_Northeast  Region_West  Purchase_Channel_In-store  \
# 0               True        False                      False
# 1              False         True                       True
# 2               True        False                      False
# 3              False        False                       True
# 4              False        False                      False
# ..               ...          ...                        ...
# 94              True        False                      False
# 95             False         True                      False
# 96             False         True                       True
# 97             False        False                       True
# 98             False        False                       True
#
#     Purchase_Channel_Online
# 0                      True
# 1                     False
# 2                      True
# 3                     False
# 4                      True
# ..                      ...
# 94                     True
# 95                     True
# 96                    False
# 97                    False
# 98                    False
#
# [98 rows x 26 columns]

# %%
y_reg
# Out:
# 0     3
# 1     4
# 2     1
# 3     1
# 4     1
#      ..
# 94    4
# 95    4
# 96    1
# 97    2
# 98    2
# Name: CLV, Length: 98, dtype: int64

# %%
x_class= processed_data.drop(['CustomerID', 'Gender', 'City', 'Region', 'Purchase_Channel', 'Churn_Status'], axis= 1)
y_class= processed_data['Churn_Status']

# %%
x_class
# Out:
#      Income  Frequency_of_Purchases  Average_Purchase_Amount  \
# 0   72504.0                  98.241                   98.241
# 1   40881.0                 157.640                  157.640
# 2   63333.0                  41.252                   41.252
# 3   58030.0                  67.329                   67.329
# 4   78889.0                  52.763                   52.763
# ..      ...                     ...                      ...
# 94  18600.0                 123.003                  123.003
# 95  68525.0                 106.526                  106.526
# 96  73538.0                 162.533                  162.533
# 97  47251.0                 145.404                  145.404
# 98  52054.0                  36.975                   36.975
#
#     Customer_Lifespan_Months  Recency  Frequency_Score  Monetary_Score  \
# 0                          3        3                2               2
# 1                          4        3                3               3
# 2                          1        4                4               4
# 3                          1        2                2               2
# 4                          1        1                1               1
# ..                       ...      ...              ...             ...
# 94                         4        4                2               3
# 95                         4        4                3               3
# 96                         1        2                1               1
# 97                         2        4                3               1
# 98                         2        1                4               4
#
#     Age_sqrt   Age_log  Customer_value  ...  Gender_Male  City_Chicago  \
# 0   7.000000  3.891820               3  ...         True          True
# 1   6.164414  3.637586               4  ...        False         False
# 2   4.123106  2.833213               1  ...         True         False
# 3   5.830952  3.526361               1  ...         True          True
# 4   5.477226  3.401197               1  ...         True         False
# ..       ...       ...             ...  ...          ...           ...
# 94  5.656854  3.465736               4  ...         True          True
# 95  6.164414  3.637586               4  ...         True          True
# 96  4.898979  3.178054               1  ...        False         False
# 97  4.472136  2.995732               2  ...        False          True
# 98  6.244998  3.663562               2  ...         True          True
#
#     City_Houston  City_Los Angeles  City_New York  Region_Midwest  \
# 0          False             False          False           False
# 1          False             False           True           False
# 2          False             False           True           False
# 3          False             False          False            True
# 4           True             False          False            True
# ..           ...               ...            ...             ...
# 94         False             False          False           False
# 95         False             False          False           False
# 96          True             False          False           False
# 97         False             False          False            True
# 98         False             False          False            True
#
#     Region_Northeast  Region_West  Purchase_Channel_In-store  \
# 0               True        False                      False
# 1              False         True                       True
# 2               True        False                      False
# 3              False        False                       True
# 4              False        False                      False
# ..               ...          ...                        ...
# 94              True        False                      False
# 95             False         True                      False
# 96             False         True                       True
# 97             False        False                       True
# 98             False        False                       True
#
#     Purchase_Channel_Online
# 0                      True
# 1                     False
# 2                      True
# 3                     False
# 4                      True
# ..                      ...
# 94                     True
# 95                     True
# 96                    False
# 97                    False
# 98                    False
#
# [98 rows x 26 columns]

# %%
y_class
# Out:
# 0     1
# 1     1
# 2     0
# 3     0
# 4     0
#      ..
# 94    1
# 95    1
# 96    1
# 97    0
# 98    0
# Name: Churn_Status, Length: 98, dtype: int64
